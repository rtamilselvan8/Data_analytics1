# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/rtamilselvan8/Data_analytics1/master/auto_clean.csv'
df=pd.read_csv(url)
af=df.head()
af.boxplot(by='aspiration',column=['city_mpg'],grid=False)
x=df.city_mpg
mean=statistics.mean(x)
print("mean is",mean)
gmean=stats.gmean(df.city_mpg)
print("gmean is",gmean)
hmean=stats.hmean(df.city_mpg)
print("hmean is",hmean)
histogram=df.city_mpg
plt.hist(histogram,bins=20)
plt.ylabel('mpg')
plt.show()
df.iloc[:20].plot.bar()
plt.show()
freq={}
for item in df.horsepower:
    if(item in freq):
        freq[item] +=1
    else:
        freq[item] =1
freq
# Out:
# mean is 25.17910447761194
# gmean is 24.393578928406477
# hmean is 23.631995367094362
# {48.0: 1,
#  52.0: 2,
#  55.0: 1,
#  56.0: 2,
#  58.0: 1,
#  60.0: 1,
#  62.0: 6,
#  64.0: 1,
#  68.0: 19,
#  69.0: 10,
#  70.0: 9,
#  72.0: 1,
#  73.0: 3,
#  76.0: 5,
#  78.0: 1,
#  82.0: 5,
#  84.0: 5,
#  85.0: 3,
#  86.0: 4,
#  88.0: 6,
#  90.0: 3,
#  92.0: 4,
#  94.0: 2,
#  95.0: 7,
#  97.0: 5,
#  100.0: 2,
#  101.0: 6,
#  102.0: 5,
#  104.2561576: 2,
#  106.0: 1,
#  110.0: 8,
#  111.0: 4,
#  112.0: 2,
#  114.0: 6,
#  115.0: 1,
#  116.0: 9,
#  120.0: 1,
#  121.0: 3,
#  123.0: 4,
#  134.0: 1,
#  135.0: 1,
#  140.0: 1,
#  142.0: 1,
#  143.0: 1,
#  145.0: 5,
#  152.0: 3,
#  154.0: 1,
#  155.0: 2,
#  156.0: 2,
#  160.0: 5,
#  161.0: 2,
#  162.0: 2,
#  175.0: 1,
#  176.0: 2,
#  182.0: 3,
#  184.0: 2,
#  200.0: 1,
#  207.0: 3,
#  262.0: 1}

# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/rtamilselvan8/Data_analytics1/master/auto_clean.csv'
df=pd.read_csv(url)
af=df.head()
af.boxplot(by='aspiration',column=['city_mpg'],grid=False)
x=df.city_mpg
mean=statistics.mean(x)
print("mean is",mean)
gmean=stats.gmean(df.city_mpg)
print("gmean is",gmean)
hmean=stats.hmean(df.city_mpg)
print("hmean is",hmean)
histogram=df.city_mpg
plt.hist(histogram,bins=20)
plt.ylabel('mpg')
plt.show()
df.iloc[:20].plot.bar()
plt.show()
freq={}
for item in df.horsepower:
    if(item in freq):
        freq[item] +=1
    else:
        freq[item] =1
freq
# Out:
# mean is 25.17910447761194
# gmean is 24.393578928406477
# hmean is 23.631995367094362
# {48.0: 1,
#  52.0: 2,
#  55.0: 1,
#  56.0: 2,
#  58.0: 1,
#  60.0: 1,
#  62.0: 6,
#  64.0: 1,
#  68.0: 19,
#  69.0: 10,
#  70.0: 9,
#  72.0: 1,
#  73.0: 3,
#  76.0: 5,
#  78.0: 1,
#  82.0: 5,
#  84.0: 5,
#  85.0: 3,
#  86.0: 4,
#  88.0: 6,
#  90.0: 3,
#  92.0: 4,
#  94.0: 2,
#  95.0: 7,
#  97.0: 5,
#  100.0: 2,
#  101.0: 6,
#  102.0: 5,
#  104.2561576: 2,
#  106.0: 1,
#  110.0: 8,
#  111.0: 4,
#  112.0: 2,
#  114.0: 6,
#  115.0: 1,
#  116.0: 9,
#  120.0: 1,
#  121.0: 3,
#  123.0: 4,
#  134.0: 1,
#  135.0: 1,
#  140.0: 1,
#  142.0: 1,
#  143.0: 1,
#  145.0: 5,
#  152.0: 3,
#  154.0: 1,
#  155.0: 2,
#  156.0: 2,
#  160.0: 5,
#  161.0: 2,
#  162.0: 2,
#  175.0: 1,
#  176.0: 2,
#  182.0: 3,
#  184.0: 2,
#  200.0: 1,
#  207.0: 3,
#  262.0: 1}

# %%
df.hist(column="city_mpg")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c1cfa2d68>]],
#       dtype=object)

# %%
freq = {} 
for item in df['city_mpg']: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1

# %%
bkey=[x for x in freq.keys()]
bkey
# Out:
# [21,
#  19,
#  24,
#  18,
#  17,
#  23,
#  20,
#  16,
#  15,
#  47,
#  38,
#  37,
#  31,
#  49,
#  30,
#  27,
#  25,
#  13,
#  26,
#  36,
#  22,
#  14,
#  45,
#  28,
#  32,
#  35,
#  34,
#  29,
#  33]

# %%
bvalue=[freq[x] for x in freq.keys()]
bvalue
# Out:
# [8,
#  27,
#  22,
#  3,
#  12,
#  12,
#  3,
#  5,
#  3,
#  1,
#  5,
#  6,
#  28,
#  1,
#  8,
#  14,
#  8,
#  1,
#  12,
#  1,
#  4,
#  2,
#  1,
#  7,
#  1,
#  1,
#  1,
#  3,
#  1]

# %%
plt.pie(bvalue,labels=bkey,startangle=90)
plt.show()

# %%
plt.bar(bkey,bvalue)
plt.show()

# %%
plt.scatter(bvalue, bkey)
plt.title('city_mpg Distribution')
freq = {} 
for item in df['city_mpg']: 
        if (item in freq): 
            freq[item] += 1
        else: 
            freq[item] = 1
plt.show()
plt.plot(df['city_mpg'].unique().tolist(),bvalue)
